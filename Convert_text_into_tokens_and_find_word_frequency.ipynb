# %%
print("Hi nlp")
# Out:
# Hi nlp

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sakshi\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\sakshi\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\sakshi\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sakshi\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\sakshi\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\sakshi\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk 
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("averaged_perceptron_tagger")
nltk.download("averaged_perceptron_tagger_eng")
nltk.download("wordnet")
nltk.download("omw-1.4")
nltk.download("maxent_ne_chunker")
nltk.download("maxent_ne_chunker_tab")
nltk.download("words")
nltk.download("treebank")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\Sakshi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

text = "Natural Language Processing is fun . NLP heips computers understand human language."

tokens = word_tokenize(text)
print("Tokens:", tokens)

freq = FreqDist(tokens)
print("\nWord Frequency:")
for word, count in freq.items():
    print(word,":", count)

print("\nMost common 5 words:", freq.most_common(5))
# Out:
# Tokens: ['Natural', 'Language', 'Processing', 'is', 'fun', '.', 'NLP', 'heips', 'computers', 'understand', 'human', 'language', '.']
#
# Word Frequency:
# Natural : 1
# Language : 1
# Processing : 1
# is : 1
# fun : 1
# . : 2
# NLP : 1
# heips : 1
# computers : 1
# understand : 1
# human : 1
# language : 1
#
# Most common 5 words: [('.', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('is', 1)]
